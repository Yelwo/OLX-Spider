# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')
olx_it_df = pd.read_csv('olxit.csv')
olx_economy_df = pd.read_csv('olxeconomy.csv')
olx_gastronomy_df = pd.read_csv('olxgastronomy.csv')
olx_cashier_df = pd.read_csv('olxcashier.csv')
olx_warehouse_df = pd.read_csv('olxwarehouse.csv')

# %%
olx_it_df['section'] = 'informatyka'
olx_economy_df['section'] = 'finanse-ksiegowosc'
olx_gastronomy_df['section'] = 'gastronomia'
olx_cashier_df['section'] = 'kasjer-ekspedient'
olx_warehouse_df['section'] = 'magazynier'
olx_df = pd.concat([olx_it_df,olx_economy_df,olx_gastronomy_df,olx_cashier_df,olx_warehouse_df])

# %%
olx_df.head()
# Out:
#                                                title      city  \
# 0  Zdobądź pracę grafika i specjalisty IT - bezpł...   Olsztyn
# 1                                Developer C# (.NET)  Oświęcim
# 2  Technik / Instalator / Monter sieci radiowych ...    Gdynia
# 3                            Programista php/Node.js   Wrocław
# 4                                   Opiekun produktu   Rzeszów
#
#             added   offer_id working_hours type_of_contract  \
# 0  14 lutego 2018  413117703    Pełny etat             Inny
# 1  15 lutego 2018  415507275    Pełny etat    Umowa o pracę
# 2  15 lutego 2018  410603797    Pełny etat   Umowa zlecenie
# 3  15 lutego 2018  414806667    Pełny etat    Umowa o pracę
# 4  15 lutego 2018  415500217    Pełny etat    Umowa o pracę
#
#                      salary  number_of_views      section
# 0                                        609  informatyka
# 1                                         33  informatyka
# 2  2 700  -  3 400 zł/mies.              378  informatyka
# 3                                         92  informatyka
# 4  3 000  -  5 000 zł/mies.              107  informatyka

# %%
olx_df.groupby('city')['title'].count().sort_values(ascending = False).head(10).plot.bar()

# %%
table
# Out:
#                    number_of_views                                  \
# type_of_contract              Inny Samozatrudnienie Umowa o dzieło
# section
# finanse-ksiegowosc     1141.400844       941.893617     579.800000
# gastronomia            1237.140351       234.666667     496.777778
# informatyka            1420.796875      1878.906977    1050.214286
# kasjer-ekspedient      1798.060606      2710.000000            NaN
# magazynier              980.611111     10178.666667     149.000000
#
#                                                      offer_id  \
# type_of_contract   Umowa o pracę Umowa zlecenie          Inny
# section
# finanse-ksiegowosc    810.096502     924.280335  3.972987e+08
# gastronomia          1817.800229    2233.643251  3.795243e+08
# informatyka          1113.210771    1435.928994  3.947904e+08
# kasjer-ekspedient    2146.449119    1714.674468  3.737735e+08
# magazynier           2155.915299    2425.264957  3.959446e+08
#
#                                                                   \
# type_of_contract   Samozatrudnienie Umowa o dzieło Umowa o pracę
# section
# finanse-ksiegowosc     4.002863e+08   4.120626e+08  3.989419e+08
# gastronomia            4.075157e+08   3.901101e+08  3.691957e+08
# informatyka            3.912981e+08   3.929084e+08  3.854677e+08
# kasjer-ekspedient      3.417266e+08            NaN  3.704526e+08
# magazynier             3.346383e+08   4.153182e+08  3.829706e+08
#
#
# type_of_contract   Umowa zlecenie
# section
# finanse-ksiegowosc   3.976812e+08
# gastronomia          3.681661e+08
# informatyka          3.915497e+08
# kasjer-ekspedient    3.837071e+08
# magazynier           3.838323e+08
